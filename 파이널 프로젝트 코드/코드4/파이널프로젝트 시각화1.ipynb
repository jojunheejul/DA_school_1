# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df21= pd.read_excel('/content/drive/MyDrive/Colab Notebooks/data/아으.. 파이널. 아으/2. 스마트스토어_상품성과_2022-01-01_2022-06-30.xlsx')
df22=pd.read_excel('/content/drive/MyDrive/Colab Notebooks/data/아으.. 파이널. 아으/2. 스마트스토어_상품성과_2022-07-01_2022-12-31.xlsx')
df23 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/data/아으.. 파이널. 아으/2. 스마트스토어_상품성과_2023-01-01_2023-03-23.xlsx')
df24 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/data/아으.. 파이널. 아으/2. 스마트스토어_상품성과_2023-03-24_2023-05-31.xlsx')
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df21.head()
# Out:
#   상품카테고리(대) 상품카테고리(중) 상품카테고리(소) 상품카테고리(세)                                 상품명  \
# 0        식품        음료        커피     원두/생두          [사업자] 클래식 블렌딩 / 1kg / 커피템플
# 1        식품        음료        커피     원두/생두  [사업자 / 골드클래스] 클래식 블렌딩 / 1kg / 커피템플
# 2     생활/건강      주방용품       잔/컵        머그      [에스프레소컵] 스페인 소믈리에 아로마챔버 에스프레소컵
# 3        식품        음료        커피     원두/생두   [대용량 / 원두커피] 클래식 블렌딩 / 1kg / 커피템플
# 4        식품        음료        커피     원두/생두    [대용량 / 원두커피] 쥬시 블렌딩 / 1kg / 커피템플
#
#          상품ID  결제수  결제상품수량  모바일비율(결제상품수량)      결제금액  모바일비율(결제금액)  상품수당 결제금액  \
# 0  6295724021   70     610       0.362295  16775000     0.362295    27500.0
# 1  5776196315   82     474       0.810127  11850000     0.810127    25000.0
# 2  6332945868   97     102       0.872549   9996000     0.872549    98000.0
# 3  5576934474   84     101       0.821782   4545000     0.821782    45000.0
# 4  5576944562   78      86       0.802326   3870000     0.802326    45000.0
#
# ...

# %% [markdown]
# 환불 정보, 인기상품, 모바일 비율
# 잘 팔리는거 / 환불 많은거/

# %%
# !pip install koreanize-matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 15.3 MB/s eta 0:00:00
# ...

# %%
df2 = pd.concat([df21, df22, df23, df24], axis=0)
sorted_df2 = df2.sort_index()


print(sorted_df2)
# Out:
#    상품카테고리(대) 상품카테고리(중) 상품카테고리(소) 상품카테고리(세)  \
# 0         식품        음료        커피     원두/생두
# 0         식품        음료        커피     원두/생두
# 0         식품        음료        커피    드립백/티백
# 0         식품        음료        커피     원두/생두
# 1         식품        음료        커피     원두/생두
# ..       ...       ...       ...       ...
# 55        식품        음료        커피     원두/생두
# 56        식품        음료        커피    드립백/티백
# 57        식품        음료        커피     원두/생두
# 58        식품        음료        커피     원두/생두
# 59        식품        음료        커피     원두/생두
#
#                                              상품명        상품ID  결제수  결제상품수량  \
# 0                     [사업자] 클래식 블렌딩 / 1kg / 커피템플  6295724021   70     610
# 0               [대용량 / 원두커피] 쥬시 블렌딩 / 1kg / 커피템플  5576944562   47      54
# 0          [원두] 게스트바리스타 프로젝트 버라이어티 팩 / 20g x 8ea  8470537740   76     106
# 0                     [사업자] 클래식 블렌딩 / 1kg / 커피템플  6295724021  129    1324
# ...

# %%
sorted_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 194 entries, 0 to 59
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   상품카테고리(대)      194 non-null    object
#  1   상품카테고리(중)      194 non-null    object
#  2   상품카테고리(소)      194 non-null    object
#  3   상품카테고리(세)      194 non-null    object
#  4   상품명            194 non-null    object
#  5   상품ID           194 non-null    int64
#  6   결제수            194 non-null    int64
#  7   결제상품수량         194 non-null    int64
#  8   모바일비율(결제상품수량)  194 non-null    float64
#  9   결제금액           194 non-null    int64
#  10  모바일비율(결제금액)    194 non-null    float64
#  11  상품수당 결제금액      194 non-null    float64
#  12  쿠폰합계           194 non-null    int64
#  13  상품쿠폰           194 non-null    int64
#  14  주문쿠폰           194 non-null    int64
#  15  환불건수           194 non-null    int64
#  16  환불금액           194 non-null    int64
# ...

# %%
sorted_df2.describe()
# Out:
#                상품ID         결제수       결제상품수량  모바일비율(결제상품수량)          결제금액  \
# count  1.940000e+02  194.000000   194.000000     194.000000  1.940000e+02
# mean   6.897864e+09   22.371134    41.396907       0.803940  1.111920e+06
# std    1.014449e+09   30.281861   115.788901       0.249764  3.191455e+06
# min    5.351764e+09    1.000000     1.000000       0.000000  1.500000e+04
# 25%    6.295719e+09    2.000000     3.000000       0.750000  1.032500e+05
# 50%    6.679485e+09   10.000000    13.000000       0.855579  3.390000e+05
# 75%    7.900271e+09   29.000000    38.000000       1.000000  8.905000e+05
# max    8.598382e+09  140.000000  1324.000000       1.000000  3.641000e+07
#
#        모바일비율(결제금액)      상품수당 결제금액          쿠폰합계          상품쿠폰   주문쿠폰  \
# count   194.000000     194.000000    194.000000    194.000000  194.0
# mean      0.803588   40800.563942   1969.072165   1969.072165    0.0
# std       0.249807   46312.669340   6242.846448   6242.846448    0.0
# ...

# %% [markdown]
# 1. 잘 팔리는 물건
# 2. 환불 많은 물건

# %%
# sorted_df2_bestbuy1 = sorted_df2.groupby('상품ID')['결제수'].sum()

# print(sorted_df2_bestbuy1)
# Out:
# 상품ID
# 5351764329    348
# 5351818905    414
# 5363173308    205
# 5363187653    218
# 5569133532    162
#              ...
# 8525754003     33
# 8548869037      1
# 8590615947      2
# 8598378782      4
# 8598381956      3
# Name: 결제수, Length: 93, dtype: int64

# %%
# quartiles = np.percentile(sorted_df2_bestbuy1, [25, 50, 75, 100])


# print("1사분위수 (25%):", quartiles[0])
# print("2사분위수 (50%):", quartiles[1])
# print("3사분위수 (75%):", quartiles[2])
# print("최댓값 (100%):", quartiles[3])
# Out:
# 1사분위수 (25%): 3.0
# 2사분위수 (50%): 12.0
# 3사분위수 (75%): 58.0
# 최댓값 (100%): 414.0

# %%
import koreanize_matplotlib
import missingno as msno

# %%
sorted_df2_bestbuy = sorted_df2.groupby('상품명')['결제수'].sum()

print(sorted_df2_bestbuy)
# Out:
# 상품명
# [ 8/26 11:00 오픈 ] 게스트바리스타 / 노스텔지아 225g / 스페셜티커피 / 카페어니언 / 커피큐레이션        17
# [16차/추가분] 게스트바리스타 /  레전드 오브 파카마라 100g / 스페셜티커피 / 304커피로스터스 / 커피큐레이션      1
# [16차] 게스트바리스타 /  레전드 오브 파카마라 100g / 스페셜티커피 / 304커피로스터스 / 커피큐레이션         54
# [16차] 게스트바리스타 /  이터널 선샤인 200g / 스페셜티커피 / 304커피로스터스 / 커피큐레이션            107
# [17차] 게스트바리스타 /  커피 포 시티 트래블러 200g / 스페셜티커피 / 톨드어스토리로스터스 / 커피큐레이션       40
#                                                                       ...
# 스페인 소믈리에 아로마챔버 에스프레소컵                                                    3
# 커피템플 30.000                                                              2
# 커피템플 원두                                                                  4
# 커피템플 캡슐                                                                  1
# 커피템플 클래식 드립백 (20박스)                                                      1
# Name: 결제수, Length: 109, dtype: int64

# %%
grouped_df = sorted_df2.groupby('상품명')['결제수'].sum()
sorted_grouped_df = grouped_df.sort_values(ascending=False)

top_30_products = sorted_grouped_df.head(30)

plt.figure(figsize=(12, 6))
plt.bar(top_30_products.index, top_30_products.values)
plt.xlabel('상품명')
plt.ylabel('결제수 합계')
plt.title('인기상품 30위')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-22-0c3c75851971>:12: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# 환불 많은것을 알아보자

# %%
sorted_df2_refund = sorted_df2.groupby('상품명')['환불수량'].sum()

print(sorted_df2_refund)
# Out:
# 상품명
# [ 8/26 11:00 오픈 ] 게스트바리스타 / 노스텔지아 225g / 스페셜티커피 / 카페어니언 / 커피큐레이션       0
# [16차/추가분] 게스트바리스타 /  레전드 오브 파카마라 100g / 스페셜티커피 / 304커피로스터스 / 커피큐레이션    0
# [16차] 게스트바리스타 /  레전드 오브 파카마라 100g / 스페셜티커피 / 304커피로스터스 / 커피큐레이션        4
# [16차] 게스트바리스타 /  이터널 선샤인 200g / 스페셜티커피 / 304커피로스터스 / 커피큐레이션            8
# [17차] 게스트바리스타 /  커피 포 시티 트래블러 200g / 스페셜티커피 / 톨드어스토리로스터스 / 커피큐레이션      3
#                                                                       ..
# 스페인 소믈리에 아로마챔버 에스프레소컵                                                  0
# 커피템플 30.000                                                            1
# 커피템플 원두                                                                0
# 커피템플 캡슐                                                                0
# 커피템플 클래식 드립백 (20박스)                                                    0
# Name: 환불수량, Length: 109, dtype: int64

# %%
sorted_df2_refund30 = sorted_df2_refund.nlargest(30)

print(sorted_df2_refund30)
# Out:
# 상품명
# [사업자] 클래식 블렌딩 / 1kg / 커피템플                                                38
# [대용량 / 원두커피] 쥬시 블렌딩 / 1kg / 커피템플                                          22
# [리미티드에디션] 게스트바리스타 / 콰트로 콜롬비아 100g / 스페셜티커피 / 모모스커피 / 커피큐레이션               21
# [원두커피] 쥬시 블렌딩 / 200g / 커피템플                                               20
# [대용량 / 원두커피] 클래식 블렌딩 / 1kg / 커피템플                                         19
# [원두] 게스트바리스타 프로젝트 버라이어티 팩 / 20g x 8ea                                     18
# [드립백커피] 쥬시 블렌딩 / 10gx10ea / 드립백 세트 / 커피템플                                 17
# [드립백커피] 클래식 블렌딩 / 10gx10ea / 드립백 세트 / 커피템플                                17
# [원두커피]클래식 블렌딩 / 200g / 커피템플                                               17
# [사업자] 쥬시 블렌딩 / 1kg / 커피템플                                                 15
# [대용량 / 원두커피] 클래식 블렌딩 / 500g / 커피템플                                        11
# [에스프레소컵] 스페인 소믈리에 아로마챔버 에스프레소컵                                            11
# ...

# %%
plt.figure(figsize=(12, 6))
plt.bar(sorted_df2_refund30.index, sorted_df2_refund30.values)
plt.xlabel('상품명')
plt.ylabel('환불 수량 합계')
plt.title('환불수량 상위 30')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-34-88041ea4c09b>:7: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# 환불 수량 말고 환불율로 바꾸자

# %% [markdown]
# #환불율 부터 계산

# %% [markdown]
# 환불비율은 이미 나와있는것의 평균으로 ㄱㄱ

# %%
refund_percent = sorted_df2.groupby('상품명')['환불비율(결제상품수량)'].mean()
print(refund_percent)
# Out:
# 상품명
# [ 8/26 11:00 오픈 ] 게스트바리스타 / 노스텔지아 225g / 스페셜티커피 / 카페어니언 / 커피큐레이션       0.000000
# [16차/추가분] 게스트바리스타 /  레전드 오브 파카마라 100g / 스페셜티커피 / 304커피로스터스 / 커피큐레이션    0.000000
# [16차] 게스트바리스타 /  레전드 오브 파카마라 100g / 스페셜티커피 / 304커피로스터스 / 커피큐레이션        0.033333
# [16차] 게스트바리스타 /  이터널 선샤인 200g / 스페셜티커피 / 304커피로스터스 / 커피큐레이션            0.068966
# [17차] 게스트바리스타 /  커피 포 시티 트래블러 200g / 스페셜티커피 / 톨드어스토리로스터스 / 커피큐레이션      0.061224
#                                                                          ...
# 스페인 소믈리에 아로마챔버 에스프레소컵                                                  0.000000
# 커피템플 30.000                                                            0.500000
# 커피템플 원두                                                                0.000000
# 커피템플 캡슐                                                                0.000000
# 커피템플 클래식 드립백 (20박스)                                                    0.000000
# Name: 환불비율(결제상품수량), Length: 109, dtype: float64

# %%
top_30_refund_percent = refund_percent.nlargest(30)

print(top_30_refund_percent)
# Out:
# 상품명
# [사업자] 클래식 블렌딩 / 1kg / 커피템플                                                        0.510495
# 커피템플 30.000                                                                       0.500000
# [사업자 / 골드클래스] 클래식 블렌딩 / 1kg / 커피템플                                                0.338153
# [샘플/사업자] 클래식 블렌딩 / 1kg / 커피템플                                                     0.266667
# [원두커피] 온두라스 라 피후다 게이샤 / 100g / 커피템플                                               0.200000
# [원두커피] 페루 COE #8 누에보 프로그레소 게이샤 / 100g / 커피템플                                      0.200000
# [원두] 게스트바리스타 프로젝트 바라이어티 팩 / 20g x 8ea                                             0.178571
# [원두] 게스트바리스타 프로젝트 버라이어티 팩 / 20g x 8ea                                             0.169811
# [캡슐커피] 대용량 커피템플 캡슐 컬렉션 4종 / 5.5gx100ea / 네스프레소 호환 커피캡슐 / 커피템플                     0.166667
# 게스트바리스타 / 댄싱베이비 250g / 스페셜티커피 / 베르크로스터스 / 커피큐레이션                                  0.153846
# ...

# %%
plt.figure(figsize=(12, 6))
plt.bar(top_30_refund_percent.index, top_30_refund_percent.values)
plt.xlabel('상품명')
plt.ylabel('평균 환불 비율')
plt.title('환불비율 상위 30')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-40-5afd4986fb6e>:7: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
df31 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/data/아으.. 파이널. 아으/3. 스마트스토어_상품_마케팅채널_2022-01-01_2022-06-30.xlsx')
df32 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/data/아으.. 파이널. 아으/3. 스마트스토어_상품_마케팅채널_2022-07-01_2022-12-31.xlsx')
df33 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/data/아으.. 파이널. 아으/3. 스마트스토어_상품_마케팅채널_2023-01-01_2023-03-23.xlsx')
df34 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/data/아으.. 파이널. 아으/3. 스마트스토어_상품_마케팅채널_2023-03-24_2023-05-31.xlsx')
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df31.head()
# Out:
#   상품카테고리(대) 상품카테고리(중) 상품카테고리(소) 상품카테고리(세)                                 상품명  \
# 0        식품        음료        커피     원두/생두          [사업자] 클래식 블렌딩 / 1kg / 커피템플
# 1        식품        음료        커피     원두/생두  [사업자 / 골드클래스] 클래식 블렌딩 / 1kg / 커피템플
# 2     생활/건강      주방용품       잔/컵        머그      [에스프레소컵] 스페인 소믈리에 아로마챔버 에스프레소컵
# 3        식품        음료        커피     원두/생두          [사업자] 클래식 블렌딩 / 1kg / 커피템플
# 4        식품        음료        커피     원두/생두           [사업자] 쥬시 블렌딩 / 1kg / 커피템플
#
#          상품ID    채널그룹     채널명    채널상세  결제수(과거 14일간 기여도추정)  결제금액(과거 14일간 기여도추정)
# 0  6295724021  (알수없음)  (알수없음)  (알수없음)           46.000000         1.221000e+07
# 1  5776196315  (알수없음)  (알수없음)  (알수없음)           68.000000         9.425000e+06
# 2  6332945868      소셜   인스타그램     NaN           32.754156         3.405907e+06
# 3  6295724021      검색   네이버검색     NaN           11.562127         2.546583e+06
# 4  6295717556  (알수없음)  (알수없음)  (알수없음)           20.000000         2.244000e+06

# %% [markdown]
# 1. 채널명
# 2. 채널명 별 결제수
# 3. 채널명 별 많이팔리는거

# %%
df3 = pd.concat([df31, df32, df33, df34], axis=0)
sorted_df3 = df3.sort_index()


print(sorted_df3)
# Out:
#     상품카테고리(대) 상품카테고리(중) 상품카테고리(소) 상품카테고리(세)  \
# 0          식품        음료        커피     원두/생두
# 0          식품        음료        커피     원두/생두
# 0          식품        음료        커피     원두/생두
# 0          식품        음료        커피     원두/생두
# 1          식품        음료        커피     원두/생두
# ..        ...       ...       ...       ...
# 284        식품        음료        커피     원두/생두
# 285        식품        음료        커피     원두/생두
# 286        식품        음료        커피    드립백/티백
# 287        식품        음료        커피     원두/생두
# 288        식품        음료        커피     원두/생두
#
#                                     상품명        상품ID    채널그룹         채널명  \
# 0            [사업자] 클래식 블렌딩 / 1kg / 커피템플  6295724021  (알수없음)      (알수없음)
# 0      [대용량 / 원두커피] 쥬시 블렌딩 / 1kg / 커피템플  5576944562  (알수없음)      (알수없음)
# 0      [대용량 / 원두커피] 쥬시 블렌딩 / 1kg / 커피템플  5576944562      검색       네이버검색
# 0            [사업자] 클래식 블렌딩 / 1kg / 커피템플  6295724021  (알수없음)      (알수없음)
# ...

# %%
sorted_df3['상품명'].unique()
# Out:
# array(['[사업자] 클래식 블렌딩 / 1kg / 커피템플', '[대용량 / 원두커피] 쥬시 블렌딩 / 1kg / 커피템플',
#        '[사업자 / 골드클래스] 클래식 블렌딩 / 1kg / 커피템플',
#        '[대용량 / 원두커피] 클래식 블렌딩 / 1kg / 커피템플',
#        '[소량/사업자] 클래식 블렌딩 / 1kg / 커피템플', '[에스프레소컵] 스페인 소믈리에 아로마챔버 에스프레소컵',
#        '[원두] 게스트바리스타 프로젝트 버라이어티 팩 / 20g x 8ea',
#        '[원두커피]클래식 블렌딩 / 200g / 커피템플',
#        '[리미티드에디션] 게스트바리스타 / 콰트로 콜롬비아 100g / 스페셜티커피 / 모모스커피 / 커피큐레이션',
#        '[사업자] 쥬시 블렌딩 / 1kg / 커피템플', '[사업자 / 원두커피] 클래식 블렌딩 / 1kg / 커피템플',
#        '[사업자] 드립백커피 4종 / 10g x 10ea',
#        '[드립백커피] 클래식 블렌딩 / 10gx10ea / 드립백 세트 / 커피템플',
#        '[드립백커피] 설 맞이 선물세트 / 콜롬비아 엘파라이소 리치 / 카페인 디카페인 / 10gx20ea / 싱글 드립백세트 / 커피템플',
#        '[드립백커피] 커피템플 컬렉션 드립백 커피 세트 4종 / 10g x 20ea',
#        '[2+1이벤트] 커피템플 대표 드립백커피 4종 쥬시, 클래식, 에티오피아, 디카프 / 10g x 10ea',
#        '[사업자] 디카페인 블렌딩 / 1kg / 커피템플',
#        '[드립백커피]  올데이 리치 / 콜롬비아 엘파라이소 리치 / 카페인 디카페인 / 10gx20ea / 싱글오리진커피 / 커피템플',
#        '[16차] 게스트바리스타 /  이터널 선샤인 200g / 스페셜티커피 / 304커피로스터스 / 커피큐레이션',
# ...

# %%
unique_products = sorted_df3['상품명'].unique()

# 고유한 값들의 개수 출력
unique_count = len(unique_products)
print(unique_count)
# Out:
# 109

# %%
grouped_df = sorted_df3.groupby('채널명').size()

print(grouped_df)
# Out:
# 채널명
# (알수없음)         151
# 구글검색             7
# 네이버 모바일메인       17
# 네이버 블로그         23
# 네이버 카페           8
# 네이버검색          137
# 네이버모바일메인-쇼핑      2
# 네이버쇼핑-검색       103
# 네이버쇼핑-서비스       74
# 네이버쇼핑-통합검색     107
# 네이버톡톡           77
# 네이버페이           11
# 웹사이트           127
# 유튜브             11
# 인스타그램           98
# 트위터              1
# 페이스북             5
# dtype: int64

# %%
top_30_df = grouped_df.nlargest(30)

plt.figure(figsize=(12, 6))
plt.bar(top_30_df.index, top_30_df.values)
plt.xticks(rotation=90)
plt.xlabel('채널명')
plt.ylabel('스마트스토어 상품 마케팅 채널에서 유입수')
plt.title('상위 30개 채널별 유입')
plt.tight_layout()
plt.show()

# %% [markdown]
# 채널명 별 결제수

# %%
buy = sorted_df3.groupby('채널명')['결제수(과거 14일간 기여도추정)'].mean()
print(buy)
# Out:
# 채널명
# (알수없음)         7.854305
# 구글검색           0.836446
# 네이버 모바일메인      0.631652
# 네이버 블로그        0.752612
# 네이버 카페         0.934774
# 네이버검색          6.124749
# 네이버모바일메인-쇼핑    0.522666
# 네이버쇼핑-검색       3.576997
# 네이버쇼핑-서비스      1.709628
# 네이버쇼핑-통합검색     3.883491
# 네이버톡톡          2.446367
# 네이버페이          5.550625
# 웹사이트           4.653568
# 유튜브            1.140670
# 인스타그램          5.160046
# 트위터            0.271439
# 페이스북           0.614459
# Name: 결제수(과거 14일간 기여도추정), dtype: float64

# %%
buy = sorted_df3.groupby('채널명')['결제수(과거 14일간 기여도추정)'].mean()

buy_sorted = buy.sort_values(ascending=False)
plt.figure(figsize=(12, 6))
buy_sorted.plot(kind='bar')
plt.xticks(rotation=90)
plt.xlabel('채널명')
plt.ylabel('평균 결제수')
plt.title('채널별 평균 결제수 ')
plt.tight_layout()
plt.show()

# %%
# channel_product_counts = sorted_df3.groupby(['채널명', '상품명']).size()
# most_sold_products_by_channel = channel_product_counts.groupby(level='채널명').idxmax().apply(lambda x: x[1])

# print(most_sold_products_by_channel)
# Out:
# 채널명
# (알수없음)                 [드립백커피] 쥬시 블렌딩 / 10gx10ea / 드립백 세트 / 커피템플
# 구글검색                            [대용량 / 원두커피] 쥬시 블렌딩 / 1kg / 커피템플
# 네이버 모바일메인                       [대용량 / 원두커피] 쥬시 블렌딩 / 1kg / 커피템플
# 네이버 블로그                        [대용량 / 원두커피] 클래식 블렌딩 / 1kg / 커피템플
# 네이버 카페         [9/30 10시오픈예정] 게스트바리스타 / 댄싱베이비 1kg / 스페셜티커피 / ...
# 네이버검색                  [드립백커피] 쥬시 블렌딩 / 10gx10ea / 드립백 세트 / 커피템플
# 네이버모바일메인-쇼핑    [2+1이벤트] 커피템플 대표 드립백커피 4종 쥬시, 클래식, 에티오피아, 디카프 ...
# 네이버쇼핑-검색               [드립백커피] 쥬시 블렌딩 / 10gx10ea / 드립백 세트 / 커피템플
# 네이버쇼핑-서비스             [드립백커피] 클래식 블렌딩 / 10gx10ea / 드립백 세트 / 커피템플
# 네이버쇼핑-통합검색             [드립백커피] 쥬시 블렌딩 / 10gx10ea / 드립백 세트 / 커피템플
# 네이버톡톡                           [대용량 / 원두커피] 쥬시 블렌딩 / 1kg / 커피템플
# 네이버페이                           [대용량 / 원두커피] 쥬시 블렌딩 / 1kg / 커피템플
# 웹사이트                   [드립백커피] 쥬시 블렌딩 / 10gx10ea / 드립백 세트 / 커피템플
# 유튜브                                  [원두커피] 쥬시 블렌딩 / 200g / 커피템플
# ...

# %%
# buy = sorted_df3.groupby('채널명')['상품명'].count()
# print(buy)
# Out:
# 채널명
# (알수없음)         151
# 구글검색             7
# 네이버 모바일메인       17
# 네이버 블로그         23
# 네이버 카페           8
# 네이버검색          137
# 네이버모바일메인-쇼핑      2
# 네이버쇼핑-검색       103
# 네이버쇼핑-서비스       74
# 네이버쇼핑-통합검색     107
# 네이버톡톡           77
# 네이버페이           11
# 웹사이트           127
# 유튜브             11
# 인스타그램           98
# 트위터              1
# 페이스북             5
# Name: 상품명, dtype: int64

# %%
buy= sorted_df3.groupby('상품명')['결제수(과거 14일간 기여도추정)'].mean()
print(buy)
# Out:
# 상품명
# [ 8/26 11:00 오픈 ] 게스트바리스타 / 노스텔지아 225g / 스페셜티커피 / 카페어니언 / 커피큐레이션        4.250000
# [16차/추가분] 게스트바리스타 /  레전드 오브 파카마라 100g / 스페셜티커피 / 304커피로스터스 / 커피큐레이션     0.500000
# [16차] 게스트바리스타 /  레전드 오브 파카마라 100g / 스페셜티커피 / 304커피로스터스 / 커피큐레이션         6.000000
# [16차] 게스트바리스타 /  이터널 선샤인 200g / 스페셜티커피 / 304커피로스터스 / 커피큐레이션            10.700000
# [17차] 게스트바리스타 /  커피 포 시티 트래블러 200g / 스페셜티커피 / 톨드어스토리로스터스 / 커피큐레이션       5.714286
#                                                                          ...
# 스페인 소믈리에 아로마챔버 에스프레소컵                                                   1.000000
# 커피템플 30.000                                                             1.000000
# 커피템플 원두                                                                 0.800000
# 커피템플 캡슐                                                                 0.500000
# 커피템플 클래식 드립백 (20박스)                                                     1.000000
# Name: 결제수(과거 14일간 기여도추정), Length: 109, dtype: float64

# %%
buy1= sorted_df3.groupby('상품명')['결제금액(과거 14일간 기여도추정)'].mean()
print(buy1)
# Out:
# 상품명
# [ 8/26 11:00 오픈 ] 게스트바리스타 / 노스텔지아 225g / 스페셜티커피 / 카페어니언 / 커피큐레이션       112500.000000
# [16차/추가분] 게스트바리스타 /  레전드 오브 파카마라 100g / 스페셜티커피 / 304커피로스터스 / 커피큐레이션     12500.000301
# [16차] 게스트바리스타 /  레전드 오브 파카마라 100g / 스페셜티커피 / 304커피로스터스 / 커피큐레이션        169444.443623
# [16차] 게스트바리스타 /  이터널 선샤인 200g / 스페셜티커피 / 304커피로스터스 / 커피큐레이션            232000.000266
# [17차] 게스트바리스타 /  커피 포 시티 트래블러 200g / 스페셜티커피 / 톨드어스토리로스터스 / 커피큐레이션      153999.999843
#                                                                            ...
# 스페인 소믈리에 아로마챔버 에스프레소컵                                                   97999.999349
# 커피템플 30.000                                                             30000.000000
# 커피템플 원두                                                                 27599.999414
# 커피템플 캡슐                                                                 30799.999512
# 커피템플 클래식 드립백 (20박스)                                                    375000.000000
# ...

# %%
# 평균 결제수를 기준으로 내림차순으로 정렬
buy1_sorted = buy1.sort_values(ascending=False)

# 상위 30개 상품만 선택
top_30_buy = buy1_sorted.head(30)

# 바차트 그리기
plt.figure(figsize=(12, 6))
top_30_buy.plot(kind='bar')
plt.xticks(rotation=90)  # X축 레이블 회전
plt.xlabel('상품명')
plt.ylabel('평균 결제금액')
plt.title('상위 30개 상품의 평균 결제금액')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-80-a2a105dafb98>:14: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
sorted_df3.head()
# Out:
#   상품카테고리(대) 상품카테고리(중) 상품카테고리(소) 상품카테고리(세)                                 상품명  \
# 0        식품        음료        커피     원두/생두          [사업자] 클래식 블렌딩 / 1kg / 커피템플
# 0        식품        음료        커피     원두/생두    [대용량 / 원두커피] 쥬시 블렌딩 / 1kg / 커피템플
# 0        식품        음료        커피     원두/생두    [대용량 / 원두커피] 쥬시 블렌딩 / 1kg / 커피템플
# 0        식품        음료        커피     원두/생두          [사업자] 클래식 블렌딩 / 1kg / 커피템플
# 1        식품        음료        커피     원두/생두  [사업자 / 골드클래스] 클래식 블렌딩 / 1kg / 커피템플
#
#          상품ID    채널그룹     채널명    채널상세  결제수(과거 14일간 기여도추정)  결제금액(과거 14일간 기여도추정)
# 0  6295724021  (알수없음)  (알수없음)  (알수없음)           46.000000         1.221000e+07
# 0  5576944562  (알수없음)  (알수없음)  (알수없음)           15.000000         7.630000e+05
# 0  5576944562      검색   네이버검색     NaN           17.037441         8.976758e+05
# 0  6295724021  (알수없음)  (알수없음)  (알수없음)          115.000000         3.190000e+07
# 1  5776196315  (알수없음)  (알수없음)  (알수없음)           68.000000         9.425000e+06

# %%
buy = sorted_df3.groupby('상품명')['결제수(과거 14일간 기여도추정)'].mean()

# 평균 결제수를 기준으로 내림차순으로 정렬
buy_sorted = buy.sort_values(ascending=False)

# 상위 30개 상품만 선택
top_30_buy = buy_sorted.head(30)

# 바차트 그리기
plt.figure(figsize=(12, 6))
top_30_buy.plot(kind='bar')
plt.xticks(rotation=90)  # X축 레이블 회전
plt.xlabel('상품명')
plt.ylabel('평균 결제수')
plt.title('상위 30개 상품의 평균 결제수')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-75-9ec230390480>:16: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
df41 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/data/아으.. 파이널. 아으/4. 스마트스토어_상품_검색채널_2022-01-01_2022-06-30.xlsx')
df42 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/data/아으.. 파이널. 아으/4. 스마트스토어_상품_검색채널_2022-07-01_2022-12-31.xlsx')
df43 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/data/아으.. 파이널. 아으/4. 스마트스토어_상품_검색채널_2023-01-01_2023-03-23.xlsx')
df44 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/data/아으.. 파이널. 아으/4. 스마트스토어_상품_검색채널_2023-03-24_2023-05-31.xlsx')
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df4 = pd.concat([df41, df42, df44, df44], axis=0)
sorted_df4 = df4.sort_index()


print(sorted_df4)
# Out:
#     상품카테고리(대) 상품카테고리(중) 상품카테고리(소) 상품카테고리(세)  \
# 0          식품        음료        커피     원두/생두
# 0          식품        음료        커피     원두/생두
# 0          식품        음료        커피     원두/생두
# 0          식품        음료        커피     원두/생두
# 1       생활/건강      주방용품       잔/컵        머그
# ..        ...       ...       ...       ...
# 229        식품        음료        커피     원두/생두
# 230        식품        음료        커피    드립백/티백
# 230        식품        음료        커피    드립백/티백
# 231        식품        음료        커피    드립백/티백
# 231        식품        음료        커피    드립백/티백
#
#                                       상품명        상품ID 채널그룹         채널명  \
# 0              [사업자] 클래식 블렌딩 / 1kg / 커피템플  6295724021   검색       네이버검색
# 0        [대용량 / 원두커피] 쥬시 블렌딩 / 1kg / 커피템플  5576944562   검색       네이버검색
# 0        [대용량 / 원두커피] 쥬시 블렌딩 / 1kg / 커피템플  5576944562   검색       네이버검색
# 0              [사업자] 클래식 블렌딩 / 1kg / 커피템플  6295724021   검색       네이버검색
# 1          [에스프레소컵] 스페인 소믈리에 아로마챔버 에스프레소컵  6332945868   검색       네이버검색
# ...

# %%
df41.head(
)
# Out:
#   상품카테고리(대) 상품카테고리(중) 상품카테고리(소) 상품카테고리(세)                                상품명  \
# 0        식품        음료        커피     원두/생두         [사업자] 클래식 블렌딩 / 1kg / 커피템플
# 1     생활/건강      주방용품       잔/컵        머그     [에스프레소컵] 스페인 소믈리에 아로마챔버 에스프레소컵
# 2        식품        음료        커피     원두/생두   [대용량 / 원두커피] 쥬시 블렌딩 / 1kg / 커피템플
# 3        식품        음료        커피     원두/생두   [대용량 / 원두커피] 쥬시 블렌딩 / 1kg / 커피템플
# 4        식품        음료        커피     원두/생두  [대용량 / 원두커피] 클래식 블렌딩 / 1kg / 커피템플
#
#          상품ID 채널그룹       채널명   키워드  결제수(과거 14일간 기여도추정)  결제금액(과거 14일간 기여도추정)
# 0  6295724021   검색     네이버검색  커피템플            6.220071         1.860980e+06
# 1  6332945868   검색     네이버검색  커피템플            9.995512         1.077560e+06
# 2  5576944562   쇼핑  네이버쇼핑-검색  커피템플            9.242614         5.499041e+05
# 3  5576944562   검색     네이버검색  커피템플           10.541133         5.193510e+05
# 4  5576934474   검색     네이버검색  커피템플            7.314721         4.798067e+05

# %% [markdown]
# 1. 상위 검색 채널명
# 2. 채널명 별 인기상품
# 3.채널명별 결재수 평균

# %%
grouped_df4 = sorted_df4.groupby('채널명').size()

print(grouped_df4)
# Out:
# 채널명
# 구글검색            7
# 네이버검색         306
# 네이버쇼핑-검색      241
# 네이버쇼핑-통합검색    337
# dtype: int64

# %%
grouped_df4 = sorted_df4.groupby('채널명').size()

# 데이터 개수를 기준으로 내림차순으로 정렬
grouped_df4_sorted = grouped_df4.sort_values(ascending=False)

# 바차트 그리기
plt.figure(figsize=(12, 6))
grouped_df4_sorted.plot(kind='bar')
plt.xticks(rotation=90)  # X축 레이블 회전
plt.xlabel('채널명')
plt.ylabel('유입')
plt.title('채널별 유입')
plt.tight_layout()
plt.show()

# %%
buy = sorted_df4.groupby('상품명')['결제수(과거 14일간 기여도추정)'].mean()

# 평균 결제수를 기준으로 내림차순으로 정렬
buy_sorted = buy.sort_values(ascending=False)

# 상위 30개 상품만 선택
top_30_buy = buy_sorted.head(30)

# 바차트 그리기
plt.figure(figsize=(12, 6))
top_30_buy.plot(kind='bar')
plt.xticks(rotation=90)  # X축 레이블 회전
plt.xlabel('상품명')
plt.ylabel('평균 결제수')
plt.title('상위 30개 상품의 평균 결제수')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-87-fb324c9da38b>:16: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
#채널명별 결재수 평균

dfa = sorted_df4.groupby('채널명')['결제수(과거 14일간 기여도추정)'].mean()

df_sorted = dfa.sort_values(ascending=False)
plt.figure(figsize=(12, 6))
df_sorted.plot(kind='bar')
plt.xticks(rotation=90)
plt.xlabel('채널명')
plt.ylabel('평균 결제수')
plt.title('채널별 평균 결제수 ')
plt.tight_layout()
plt.show()

# %%
df81=pd.read_excel('/content/drive/MyDrive/Colab Notebooks/data/아으.. 파이널. 아으/8. 스마트스토어_배송통계_2022-01-01_2022-06-30.xlsx')

# %%
df81.head()
# Out:
#            날짜  배송유형  결제건수(상품주문번호)    결제금액  발송건수  발송일준수건수  발송일준수율  배송완료건수  \
# 0  2022-06-30  일반배송             5  169000     1        1     1.0      20
# 1  2022-06-29  일반배송             2  153500     7        7     1.0      11
# 2  2022-06-28  일반배송            15  724000    18       18     1.0       4
# 3  2022-06-27  일반배송            16  664000    15       15     1.0       9
# 4  2022-06-26  일반배송             6  417500     0        0     NaN       0
#
#    배송완료일준수건수  배송완료일준수율  평균배송기간(일)  배송기간48시간내건수  배송시간48시간내비율
# 0          0       NaN   2.878035            0     0.000000
# 1          0       NaN   2.266803            2     0.181818
# 2          0       NaN   2.265929            1     0.250000
# 3          0       NaN   1.713762            8     0.888889
# 4          0       NaN   0.000000            0          NaN

# %%
detail = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/data/아으.. 파이널. 아으/커피템플_상세_데이터_220201_220228.xlsx')

# %%
detail.head()
# Out:
#           결제일      결제시간 주문 채널          결제내역     합계 상품별 할인 결제 할인  카드 결제 현금 결제  \
# 0  2022-02-28  18:24:04    셀러  드립백 클래식 외 1건  18100      -     -  18100     -
# 1         NaN       NaN   NaN           NaN    NaN    NaN   NaN    NaN   NaN
# 2  2022-02-28  18:23:51    셀러  드립백 클래식 외 1건  18100      -     -  18100     -
# 3         NaN       NaN   NaN           NaN    NaN    NaN   NaN    NaN   NaN
# 4  2022-02-28  18:12:49    셀러   캡슐 클래식 외 2건  30100      -     -  30100     -
#
#   간편 결제  ...   환불 환불 일시 배달팁(매출 포함x)    카테고리      상품명 옵션 수량 상품별 단가 상품별 합계 결제메모
# 0     -  ...    -     -           -   블렌딩원두      종이백  -  1    100    100    -
# 1   NaN  ...  NaN   NaN         NaN  드립백/캡슐  드립백 클래식  -  1  18000  18000  NaN
# 2     -  ...    -     -           -  드립백/캡슐  드립백 클래식  -  1  18000  18000    -
# 3   NaN  ...  NaN   NaN         NaN   블렌딩원두      종이백  -  1    100    100  NaN
# 4     -  ...    -     -           -  드립백/캡슐   캡슐 클래식  -  1  15000  15000    -
#
# [5 rows x 25 columns]

# %%
human = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/data/아으.. 파이널. 아으/5. 스마트스토어_상품_인구통계_2022-01-01_2022-06-30.xlsx')

# %%
human.head()
# Out:
#   상품카테고리(대) 상품카테고리(중) 상품카테고리(소) 상품카테고리(세)                                 상품명  \
# 0        식품        음료        커피     원두/생두          [사업자] 클래식 블렌딩 / 1kg / 커피템플
# 1        식품        음료        커피     원두/생두          [사업자] 클래식 블렌딩 / 1kg / 커피템플
# 2        식품        음료        커피     원두/생두  [사업자 / 골드클래스] 클래식 블렌딩 / 1kg / 커피템플
# 3        식품        음료        커피     원두/생두  [사업자 / 골드클래스] 클래식 블렌딩 / 1kg / 커피템플
# 4     생활/건강      주방용품       잔/컵        머그      [에스프레소컵] 스페인 소믈리에 아로마챔버 에스프레소컵
#
#          상품ID  성별     나이      결제금액  결제수  결제상품수량    환불금액  환불건수  환불수량
# 0  6295724021  여성  31~35  10230000   18     372       0     0     0
# 1  6295724021  남성  36~40   3712500   29     135       0     0     0
# 2  5776196315  남성  41~45   3400000   23     136       0     0     0
# 3  5776196315  여성  41~45   3050000   14     122       0     0     0
# 4  6332945868  남성  31~35   2940000   28      30  490000     5     5
